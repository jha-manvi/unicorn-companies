# %%
import pandas as pd

# Load the data from the CSV file into a pandas DataFrame
df = pd.read_csv('Unicorn_Companies_cleaned.csv')

# Apply the split and explode operations on 'Column2'
result_df = df.assign(Column2=df['Select Investors'].str.split(',')).explode('Select Investors').reset_index(drop=True)

# Print the final DataFrame
print(result_df)
# Out:
#           Company     Valuation Date Joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial Intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-Commerce & Direct-To-Consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-Commerce & Direct-To-Consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-Commerce & Direct-To-Consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & Retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-Commerce & Direct-To-Consumer
#
# ...

# %%
result_df
# Out:
#           Company     Valuation Date Joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial Intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-Commerce & Direct-To-Consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-Commerce & Direct-To-Consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-Commerce & Direct-To-Consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & Retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-Commerce & Direct-To-Consumer
#
# ...

# %%
import pandas as pd

# Load the data from the CSV file into a pandas DataFrame
df = pd.read_csv('Unicorn_Companies_cleaned.csv')

# Create an empty DataFrame to store the results
result_df = pd.DataFrame(columns=df.columns)

# Iterate through each row in the original DataFrame
for index, row in df.iterrows():
    # Split the comma-separated values in 'Column2'
    values = str(row[('Select Investors')]).split(',')
    
    # Create a new row for each value in 'Column2' and copy 'Column1'
    for value in values:
        new_row = row.copy()
        new_row['Select Investors'] = value.strip()  # Remove extra spaces if any
        result_df = result_df.append(new_row, ignore_index=True)

# Print the final DataFrame
result_df
# Out:
#         Company     Valuation Date Joined                         Industry  \
# 0     Bytedance  180000000000  2017-04-07          Artificial Intelligence
# 1     Bytedance  180000000000  2017-04-07          Artificial Intelligence
# 2     Bytedance  180000000000  2017-04-07          Artificial Intelligence
# 3     Bytedance  180000000000  2017-04-07          Artificial Intelligence
# 4        SpaceX  100000000000  2012-12-01                            Other
# ...         ...           ...         ...                              ...
# 3049       Zopa    1000000000  2021-10-19                          Fintech
# 3050       Zopa    1000000000  2021-10-19                          Fintech
# 3051      Zwift    1000000000  2020-09-16  E-Commerce & Direct-To-Consumer
# 3052      Zwift    1000000000  2020-09-16  E-Commerce & Direct-To-Consumer
# 3053      Zwift    1000000000  2020-09-16  E-Commerce & Direct-To-Consumer
#
# ...

# %%
result_df

# %%
result_df.to_csv('Investors.csv')
